# %%
import steamreviews
import pandas as pd

request_params = dict()
# Reference: https://partner.steamgames.com/doc/store/localization#supported_languages
request_params['language'] = 'english'
request_params['filter'] = 'recent'
request_params['day_range'] = '28'
# Reference: https://partner.steamgames.com/doc/store/getreviews

appids = pd.read_csv('idlist.txt')

# %%
steamreviews.download_reviews_for_app_id_batch(chosen_request_params=request_params)
# Out:
# Loading idlist.txt
# Loading idprocessed_on_20250131.txt
# Skipping previously found appID = None
# Skipping previously found appID = 10
# Skipping previously found appID = 20
# Skipping previously found appID = 40
# Skipping previously found appID = 50
# Skipping previously found appID = 60
# Skipping previously found appID = 70
# Skipping previously found appID = 80
# Skipping previously found appID = 130
# Skipping previously found appID = 220
# Skipping previously found appID = 240
# Skipping previously found appID = 280
# Skipping previously found appID = 300
# Skipping previously found appID = 320
# Skipping previously found appID = 340
# Skipping previously found appID = 360
# Skipping previously found appID = 380
# Skipping previously found appID = 400
# Skipping previously found appID = 420
# Skipping previously found appID = 440
# Skipping previously found appID = 500
# Skipping previously found appID = 550
# Skipping previously found appID = 570
# Skipping previously found appID = 620
# Skipping previously found appID = 630
# Skipping previously found appID = 730
# Skipping previously found appID = 1250
# Skipping previously found appID = 1840
# Skipping previously found appID = 2100
# Skipping previously found appID = 2280
# Skipping previously found appID = 2310
# Skipping previously found appID = 2630
# Skipping previously found appID = 3590
# Skipping previously found appID = 3830
# Skipping previously found appID = 3910
# Skipping previously found appID = 4000
# Skipping previously found appID = 4500
# Skipping previously found appID = 4560
# Skipping previously found appID = 4570
# Skipping previously found appID = 4580
# Skipping previously found appID = 4700
# Skipping previously found appID = 4760
# Skipping previously found appID = 4920
# Skipping previously found appID = 6000
# Skipping previously found appID = 6020
# Skipping previously found appID = 6060
# Skipping previously found appID = 6850
# Skipping previously found appID = 6860
# Skipping previously found appID = 6880
# Skipping previously found appID = 6900
# Skipping previously found appID = 6910
# Skipping previously found appID = 7670
# Skipping previously found appID = 7760
# Skipping previously found appID = 7940
# Skipping previously found appID = 8190
# Skipping previously found appID = 8500
# Skipping previously found appID = 8850
# Skipping previously found appID = 8870
# Skipping previously found appID = 8930
# Skipping previously found appID = 8980
# Skipping previously found appID = 9010
# Skipping previously found appID = 9340
# Skipping previously found appID = 9480
# Skipping previously found appID = 9900
# Skipping previously found appID = 10090
# Skipping previously found appID = 10180
# Skipping previously found appID = 10500
# Skipping previously found appID = 10680
# Skipping previously found appID = 11020
# Skipping previously found appID = 12100
# Skipping previously found appID = 12110
# Skipping previously found appID = 12120
# Skipping previously found appID = 12200
# Skipping previously found appID = 12210
# Skipping previously found appID = 12220
# Skipping previously found appID = 13520
# Skipping previously found appID = 15100
# Skipping previously found appID = 15620
# Skipping previously found appID = 15700
# Skipping previously found appID = 17080
# Skipping previously found appID = 17300
# Skipping previously found appID = 17330
# Skipping previously found appID = 17390
# Skipping previously found appID = 17410
# Skipping previously found appID = 17460
# Skipping previously found appID = 17470
# Skipping previously found appID = 17480
# Skipping previously found appID = 19680
# Skipping previously found appID = 19900
# Skipping previously found appID = 20510
# Skipping previously found appID = 20570
# Skipping previously found appID = 20900
# Skipping previously found appID = 20920
# Skipping previously found appID = 21690
# Skipping previously found appID = 22320
# Skipping previously found appID = 22330
# Skipping previously found appID = 22350
# Skipping previously found appID = 22370
# Skipping previously found appID = 22380
# Skipping previously found appID = 24010
# Skipping previously found appID = 24200
# Skipping previously found appID = 24240
# Skipping previously found appID = 24740
# Skipping previously found appID = 24780
# Skipping previously found appID = 24960
# Skipping previously found appID = 24980
# Skipping previously found appID = 26800
# Skipping previously found appID = 32370
# Skipping previously found appID = 32430
# Skipping previously found appID = 32470
# Skipping previously found appID = 33230
# Skipping previously found appID = 33900
# Skipping previously found appID = 33930
# Skipping previously found appID = 34030
# Skipping previously found appID = 34270
# Skipping previously found appID = 34870
# Skipping previously found appID = 35140
# Skipping previously found appID = 35450
# Skipping previously found appID = 35700
# Skipping previously found appID = 35720
# Skipping previously found appID = 38400
# Skipping previously found appID = 38420
# Skipping previously found appID = 39120
# Skipping previously found appID = 39140
# Skipping previously found appID = 39210
# Skipping previously found appID = 39500
# Skipping previously found appID = 40100
# Skipping previously found appID = 40800
# Skipping previously found appID = 40990
# Skipping previously found appID = 41000
# Skipping previously found appID = 41070
# Skipping previously found appID = 41500
# Skipping previously found appID = 41700
# Skipping previously found appID = 42700
# Skipping previously found appID = 42910
# Skipping previously found appID = 47780
# Skipping previously found appID = 47790
# Skipping previously found appID = 47810
# Skipping previously found appID = 47870
# Skipping previously found appID = 47890
# Skipping previously found appID = 48000
# Skipping previously found appID = 48190
# Skipping previously found appID = 48700
# Skipping previously found appID = 49520
# Skipping previously found appID = 50130
# Skipping previously found appID = 50300
# Skipping previously found appID = 50620
# Skipping previously found appID = 55100
# Skipping previously found appID = 55110
# Skipping previously found appID = 55150
# Skipping previously found appID = 55230
# Skipping previously found appID = 56437
# Skipping previously found appID = 57690
# Skipping previously found appID = 63380
# Skipping previously found appID = 65790
# Skipping previously found appID = 65800
# Skipping previously found appID = 65930
# Skipping previously found appID = 65980
# Skipping previously found appID = 67370
# Skipping previously found appID = 70000
# Skipping previously found appID = 72850
# Skipping previously found appID = 96000
# Skipping previously found appID = 96100
# Skipping previously found appID = 99900
# Skipping previously found appID = 102500
# Skipping previously found appID = 102600
# Skipping previously found appID = 104900
# Skipping previously found appID = 105450
# Skipping previously found appID = 105600
# Skipping previously found appID = 107100
# Skipping previously found appID = 107410
# Skipping previously found appID = 108600
# Skipping previously found appID = 108710
# Skipping previously found appID = 108800
# Skipping previously found appID = 109600
# Skipping previously found appID = 110800
# Skipping previously found appID = 113020
# Skipping previously found appID = 113200
# Skipping previously found appID = 113400
# Skipping previously found appID = 113420
# Skipping previously found appID = 115300
# Skipping previously found appID = 200210
# Skipping previously found appID = 200260
# Skipping previously found appID = 200510
# Skipping previously found appID = 200710
# Skipping previously found appID = 201270
# Skipping previously found appID = 201790
# Skipping previously found appID = 201810
# Skipping previously found appID = 202170
# Skipping previously found appID = 202750
# Skipping previously found appID = 202970
# Skipping previously found appID = 203140
# Skipping previously found appID = 203160
# Skipping previously found appID = 203290
# Skipping previously found appID = 203770
# Skipping previously found appID = 204100
# Skipping previously found appID = 204300
# Skipping previously found appID = 204340
# Skipping previously found appID = 204360
# Skipping previously found appID = 204450
# Skipping previously found appID = 204880
# Skipping previously found appID = 205100
# Skipping previously found appID = 206210
# Skipping previously found appID = 206420
# Skipping previously found appID = 206440
# Skipping previously found appID = 206480
# Skipping previously found appID = 206500
# Skipping previously found appID = 207140
# Skipping previously found appID = 207230
# Skipping previously found appID = 207610
# Skipping previously found appID = 208090
# Skipping previously found appID = 208140
# Skipping previously found appID = 208580
# Skipping previously found appID = 208650
# Skipping previously found appID = 209000
# Skipping previously found appID = 209080
# Skipping previously found appID = 209160
# Skipping previously found appID = 209670
# Skipping previously found appID = 209870
# Skipping previously found appID = 210770
# Skipping previously found appID = 211420
# Skipping previously found appID = 211500
# Skipping previously found appID = 211820
# Skipping previously found appID = 212070
# Skipping previously found appID = 212500
# Skipping previously found appID = 212680
# Skipping previously found appID = 213670
# Skipping previously found appID = 214420
# Skipping previously found appID = 214490
# Skipping previously found appID = 214560
# Skipping previously found appID = 214950
# Skipping previously found appID = 215080
# Skipping previously found appID = 215280
# Skipping previously found appID = 216150
# Skipping previously found appID = 218230
# Skipping previously found appID = 218620
# Skipping previously found appID = 218680
# Skipping previously found appID = 219150
# Skipping previously found appID = 219640
# Skipping previously found appID = 219740
# Skipping previously found appID = 219990
# Skipping previously found appID = 220200
# Skipping previously found appID = 220240
# Skipping previously found appID = 220440
# Skipping previously found appID = 221040
# Skipping previously found appID = 221100
# Skipping previously found appID = 221380
# Skipping previously found appID = 221910
# Skipping previously found appID = 222880
# Skipping previously found appID = 223470
# Skipping previously found appID = 223710
# Skipping previously found appID = 223750
# Skipping previously found appID = 224260
# Skipping previously found appID = 224600
# Skipping previously found appID = 224760
# Skipping previously found appID = 225080
# Skipping previously found appID = 225260
# Skipping previously found appID = 225540
# Skipping previously found appID = 225840
# Skipping previously found appID = 226840
# Skipping previously found appID = 227300
# Skipping previously found appID = 227940
# Skipping previously found appID = 228200
# Skipping previously found appID = 228280
# Skipping previously found appID = 230230
# Skipping previously found appID = 230290
# Skipping previously found appID = 230410
# Skipping previously found appID = 231060
# Skipping previously found appID = 231430
# Skipping previously found appID = 232050
# Skipping previously found appID = 232090
# Skipping previously found appID = 232770
# Skipping previously found appID = 232890
# Skipping previously found appID = 233130
# Skipping previously found appID = 233450
# Skipping previously found appID = 233720
# Skipping previously found appID = 233860
# Skipping previously found appID = 234140
# Skipping previously found appID = 234650
# Skipping previously found appID = 235460
# Skipping previously found appID = 235540
# Skipping previously found appID = 235600
# Skipping previously found appID = 236110
# Skipping previously found appID = 236390
# Skipping previously found appID = 236850
# Skipping previously found appID = 236870
# Skipping previously found appID = 237110
# Skipping previously found appID = 237310
# Skipping previously found appID = 237930
# Skipping previously found appID = 238010
# Skipping previously found appID = 955050
# Skipping previously found appID = 960090
# Skipping previously found appID = 961200
# Skipping previously found appID = 962130
# Skipping previously found appID = 967050
# Skipping previously found appID = 975370
# Skipping previously found appID = 976310
# Skipping previously found appID = 976730
# Skipping previously found appID = 977950
# Skipping previously found appID = 979690
# Skipping previously found appID = 990080
# Skipping previously found appID = 992300
# Skipping previously found appID = 1016920
# Skipping previously found appID = 1017180
# Skipping previously found appID = 1029690
# Skipping previously found appID = 1030830
# Skipping previously found appID = 1030840
# Skipping previously found appID = 1046930
# Skipping previously found appID = 1049410
# Skipping previously found appID = 1049590
# Skipping previously found appID = 1056640
# Skipping previously found appID = 1056960
# Skipping previously found appID = 1057090
# Skipping previously found appID = 1057240
# Skipping previously found appID = 1058020
# Skipping previously found appID = 1061910
# Skipping previously found appID = 1063730
# Skipping previously found appID = 1085660
# Skipping previously found appID = 1086940
# Skipping previously found appID = 1089090
# Skipping previously found appID = 1089350
# Skipping previously found appID = 1089980
# Skipping previously found appID = 1091500
# Skipping previously found appID = 1092790
# Skipping previously found appID = 1094520
# Skipping previously found appID = 1097150
# Skipping previously found appID = 1100600
# Skipping previously found appID = 1113000
# Skipping previously found appID = 1116170
# Skipping previously found appID = 1118200
# Skipping previously found appID = 1128810
# Skipping previously found appID = 1129580
# Skipping previously found appID = 1139900
# Skipping previously found appID = 1142710
# Skipping previously found appID = 1144200
# Skipping previously found appID = 1145350
# Skipping previously found appID = 1145360
# Skipping previously found appID = 1147550
# Skipping previously found appID = 1147560
# Skipping previously found appID = 1150690
# Skipping previously found appID = 1151340
# Skipping previously found appID = 1151640
# Skipping previously found appID = 1158310
# Skipping previously found appID = 1167630
# Skipping previously found appID = 1172380
# Skipping previously found appID = 1172470
# Skipping previously found appID = 1172620
# Skipping previously found appID = 1174180
# Skipping previously found appID = 1178830
# Skipping previously found appID = 1180380
# Skipping previously found appID = 1190000
# Skipping previously found appID = 1196590
# Skipping previously found appID = 1203220
# Skipping previously found appID = 1203620
# Skipping previously found appID = 1211020
# Skipping previously found appID = 1213210
# Skipping previously found appID = 1217060
# Skipping previously found appID = 1222140
# Skipping previously found appID = 1222670
# Skipping previously found appID = 1222680
# Skipping previously found appID = 1222700
# Skipping previously found appID = 1225330
# Skipping previously found appID = 1229490
# Skipping previously found appID = 1237950
# Skipping previously found appID = 1237970
# Skipping previously found appID = 1238810
# Skipping previously found appID = 1238820
# Skipping previously found appID = 1238840
# Skipping previously found appID = 1238860
# Skipping previously found appID = 1240440
# Skipping previously found appID = 1241100
# Skipping previously found appID = 1245620
# Skipping previously found appID = 1248130
# Skipping previously found appID = 1250410
# Skipping previously found appID = 1254120
# Skipping previously found appID = 1259420
# Skipping previously found appID = 1260320
# Skipping previously found appID = 1262350
# Skipping previously found appID = 1262580
# Skipping previously found appID = 1263850
# Skipping previously found appID = 1272080
# Skipping previously found appID = 1274570
# Skipping previously found appID = 1277400
# Skipping previously found appID = 1282100
# Skipping previously found appID = 1282730
# Skipping previously found appID = 1284210
# Skipping previously found appID = 1284410
# Skipping previously found appID = 1286680
# Skipping previously found appID = 1286830
# Skipping previously found appID = 1289310
# Skipping previously found appID = 1290000
# Skipping previously found appID = 1293830
# Skipping previously found appID = 1296830
# Skipping previously found appID = 1301720
# Skipping previously found appID = 1304930
# Skipping previously found appID = 1313140
# Skipping previously found appID = 1313860
# Skipping previously found appID = 1326470
# Skipping previously found appID = 1332010
# Skipping previously found appID = 1343370
# Skipping previously found appID = 1343400
# Skipping previously found appID = 1353950
# Skipping previously found appID = 1361210
# Skipping previously found appID = 1363080
# Skipping previously found appID = 1364780
# Skipping previously found appID = 1366540
# Skipping previously found appID = 1366800
# Skipping previously found appID = 1371980
# Skipping previously found appID = 1372880
# Skipping previously found appID = 1377580
# Skipping previously found appID = 1380400
# Skipping previously found appID = 1384160
# Skipping previously found appID = 1388770
# Skipping previously found appID = 1399780
# Skipping previously found appID = 1404210
# Skipping previously found appID = 1407200
# Skipping previously found appID = 1408720
# Skipping previously found appID = 1426210
# Skipping previously found appID = 1446780
# Skipping previously found appID = 1454400
# Skipping previously found appID = 1466640
# Skipping previously found appID = 1466860
# Skipping previously found appID = 1468810
# Skipping previously found appID = 1475810
# Skipping previously found appID = 1476970
# Skipping previously found appID = 1483870
# Skipping previously found appID = 1506830
# Skipping previously found appID = 1509960
# Skipping previously found appID = 1515950
# Skipping previously found appID = 1517290
# Skipping previously found appID = 1520470
# Skipping previously found appID = 1522820
# Skipping previously found appID = 1533390
# Skipping previously found appID = 1536610
# Skipping previously found appID = 1549970
# Skipping previously found appID = 1551360
# Skipping previously found appID = 1557740
# Skipping previously found appID = 1562430
# Skipping previously found appID = 1569040
# Skipping previously found appID = 1593500
# Skipping previously found appID = 1599340
# Skipping previously found appID = 1604030
# Skipping previously found appID = 1610430
# Skipping previously found appID = 1611910
# Skipping previously found appID = 1619450
# Skipping previously found appID = 1621690
# Downloading reviews for appID = 1623730
# [appID = 1623730] expected #reviews = 148934
# [appID = 1623730] num_reviews = 2993 (expected: 148934)
# Downloading reviews for appID = 1627140
# [appID = 1627140] num_reviews = 0 (expected: -1)
# Downloading reviews for appID = 1637320
# [appID = 1637320] expected #reviews = 9255
# [appID = 1637320] num_reviews = 199 (expected: 9255)
# Downloading reviews for appID = 1643320
# [appID = 1643320] expected #reviews = 43643
# [appID = 1643320] num_reviews = 2535 (expected: 43643)
# Downloading reviews for appID = 1659040
# [appID = 1659040] expected #reviews = 21555
# [appID = 1659040] num_reviews = 821 (expected: 21555)
# Downloading reviews for appID = 1676130
# [appID = 1676130] expected #reviews = 2271
# [appID = 1676130] num_reviews = 17 (expected: 2271)
# Downloading reviews for appID = 1677740
# [appID = 1677740] expected #reviews = 29271
# [appID = 1677740] num_reviews = 331 (expected: 29271)
# Downloading reviews for appID = 1687950
# [appID = 1687950] expected #reviews = 29073
# [appID = 1687950] num_reviews = 699 (expected: 29073)
# Downloading reviews for appID = 1716740
# [appID = 1716740] expected #reviews = 110857
# [appID = 1716740] num_reviews = 375 (expected: 110857)
# Downloading reviews for appID = 1721470
# [appID = 1721470] expected #reviews = 35872
# [appID = 1721470] num_reviews = 982 (expected: 35872)
# Downloading reviews for appID = 1755910
# [appID = 1755910] expected #reviews = 352
# [appID = 1755910] num_reviews = 5 (expected: 352)
# Downloading reviews for appID = 1790600
# [appID = 1790600] expected #reviews = 32421
# [appID = 1790600] num_reviews = 768 (expected: 32421)
# Downloading reviews for appID = 1794680
# [appID = 1794680] expected #reviews = 125696
# [appID = 1794680] num_reviews = 662 (expected: 125696)
# Downloading reviews for appID = 1811260
# [appID = 1811260] expected #reviews = 43192
# [appID = 1811260] num_reviews = 52 (expected: 43192)
# Downloading reviews for appID = 1817070
# [appID = 1817070] expected #reviews = 59543
# [appID = 1817070] num_reviews = 1122 (expected: 59543)
# Downloading reviews for appID = 1818750
# [appID = 1818750] expected #reviews = 75164
# [appID = 1818750] num_reviews = 112 (expected: 75164)
# Downloading reviews for appID = 1824220
# [appID = 1824220] expected #reviews = 22777
# [appID = 1824220] num_reviews = 405 (expected: 22777)
# Downloading reviews for appID = 1832640
# [appID = 1832640] expected #reviews = 2614
# [appID = 1832640] num_reviews = 6 (expected: 2614)
# Downloading reviews for appID = 1845910
# [appID = 1845910] expected #reviews = 26172
# Number of queries 150 reached. Cooldown: 310 seconds
# [appID = 1845910] num_reviews = 1613 (expected: 26172)
# Downloading reviews for appID = 1868140
# [appID = 1868140] expected #reviews = 44245
# [appID = 1868140] num_reviews = 682 (expected: 44245)
# Downloading reviews for appID = 1888160
# [appID = 1888160] expected #reviews = 45296
# [appID = 1888160] num_reviews = 610 (expected: 45296)
# Downloading reviews for appID = 1904540
# [appID = 1904540] expected #reviews = 7782
# [appID = 1904540] num_reviews = 14 (expected: 7782)
# Downloading reviews for appID = 1929610
# [appID = 1929610] expected #reviews = 11742
# [appID = 1929610] num_reviews = 303 (expected: 11742)
# Downloading reviews for appID = 1938090
# [appID = 1938090] expected #reviews = 334641
# [appID = 1938090] num_reviews = 3905 (expected: 334641)
# Downloading reviews for appID = 1942280
# [appID = 1942280] expected #reviews = 24651
# [appID = 1942280] num_reviews = 625 (expected: 24651)
# Downloading reviews for appID = 1943950
# [appID = 1943950] expected #reviews = 33778
# [appID = 1943950] num_reviews = 813 (expected: 33778)
# Downloading reviews for appID = 1966720
# [appID = 1966720] expected #reviews = 322810
# [appID = 1966720] num_reviews = 3109 (expected: 322810)
# Downloading reviews for appID = 1987080
# [appID = 1987080] expected #reviews = 12630
# [appID = 1987080] num_reviews = 76 (expected: 12630)
# Downloading reviews for appID = 2050650
# [appID = 2050650] expected #reviews = 63115
# [appID = 2050650] num_reviews = 1072 (expected: 63115)
# Downloading reviews for appID = 2054970
# [appID = 2054970] expected #reviews = 55115
# Number of queries 150 reached. Cooldown: 310 seconds
# [appID = 2054970] num_reviews = 464 (expected: 55115)
# Downloading reviews for appID = 2096600
# [appID = 2096600] expected #reviews = 1374
# [appID = 2096600] num_reviews = 45 (expected: 1374)
# Downloading reviews for appID = 2183900
# [appID = 2183900] expected #reviews = 89234
# [appID = 2183900] num_reviews = 2542 (expected: 89234)
# Downloading reviews for appID = 2186680
# [appID = 2186680] expected #reviews = 15856
# [appID = 2186680] num_reviews = 792 (expected: 15856)
# Downloading reviews for appID = 2195250
# [appID = 2195250] expected #reviews = 35580
# [appID = 2195250] num_reviews = 259 (expected: 35580)
# Downloading reviews for appID = 2215430
# [appID = 2215430] expected #reviews = 32123
# [appID = 2215430] num_reviews = 968 (expected: 32123)
# Downloading reviews for appID = 2231450
# [appID = 2231450] expected #reviews = 45682
# [appID = 2231450] num_reviews = 478 (expected: 45682)
# Downloading reviews for appID = 2322010
# [appID = 2322010] expected #reviews = 11398
# [appID = 2322010] num_reviews = 1209 (expected: 11398)
# Downloading reviews for appID = 2322560
# [appID = 2322560] expected #reviews = 1542
# [appID = 2322560] num_reviews = 11 (expected: 1542)
# Downloading reviews for appID = 2358720
# [appID = 2358720] expected #reviews = 71398
# [appID = 2358720] num_reviews = 1681 (expected: 71398)
# Downloading reviews for appID = 2379780
# [appID = 2379780] expected #reviews = 76158
# Number of queries 150 reached. Cooldown: 310 seconds
# [appID = 2379780] num_reviews = 8655 (expected: 76158)
# Downloading reviews for appID = 2399830
# [appID = 2399830] expected #reviews = 41119
# [appID = 2399830] num_reviews = 1000 (expected: 41119)
# Downloading reviews for appID = 2479810
# [appID = 2479810] expected #reviews = 37474
# [appID = 2479810] num_reviews = 418 (expected: 37474)
# Downloading reviews for appID = 2567870
# [appID = 2567870] expected #reviews = 19510
# [appID = 2567870] num_reviews = 459 (expected: 19510)
# Downloading reviews for appID = 2670630
# [appID = 2670630] expected #reviews = 26293
# [appID = 2670630] num_reviews = 952 (expected: 26293)
# Downloading reviews for appID = 2694490
# [appID = 2694490] expected #reviews = 80168
# Number of queries 150 reached. Cooldown: 310 seconds
# [appID = 2694490] num_reviews = 14370 (expected: 80168)
# Downloading reviews for appID = 2835570
# [appID = 2835570] expected #reviews = 26995
# [appID = 2835570] num_reviews = 1555 (expected: 26995)
# Downloading reviews for appID = 2881650
# [appID = 2881650] expected #reviews = 62170
# [appID = 2881650] num_reviews = 1839 (expected: 62170)
# Downloading reviews for appID = 3070070
# [appID = 3070070] expected #reviews = 25623
# [appID = 3070070] num_reviews = 1058 (expected: 25623)
# Downloading reviews for appID = 3097560
# [appID = 3097560] expected #reviews = 13468
# [appID = 3097560] num_reviews = 1011 (expected: 13468)
# Downloading reviews for appID = 3146520
# [appID = 3146520] expected #reviews = 54040
# Number of queries 150 reached. Cooldown: 310 seconds
# [appID = 3146520] num_reviews = 2792 (expected: 54040)
# Game records written: 50
# True

# %%
import pandas as pd
import json
import os
from tqdm import tqdm  # For progress bar

def process_json_files(data_dir="Data", output_file="all_reviews.csv"):
    # Initialize empty list to store DataFrames
    all_dfs = []
    
    # Get list of JSON files
    files = [f for f in os.listdir(data_dir) if f.startswith("review_") and f.endswith(".json")]
    
    for filename in tqdm(files, desc="Processing JSON files"):
        try:
            # Extract game ID from filename
            game_id = filename.split("_")[1].split(".")[0]
            
            # Load JSON data
            with open(os.path.join(data_dir, filename), 'r', encoding='utf-8') as f:
                data = json.load(f)
            
            # Skip files without reviews
            if 'reviews' not in data or not data['reviews']:
                continue
                
            # Convert reviews to DataFrame
            reviews_list = list(data['reviews'].values())
            df = pd.json_normalize(reviews_list, sep='_')
            
            # Add game ID column
            df['game_id'] = game_id
            
            # Append to list
            all_dfs.append(df)
            
        except Exception as e:
            print(f"Error processing {filename}: {str(e)}")
            continue
    
    # Combine all DataFrames
    combined_df = pd.concat(all_dfs, ignore_index=True)
    
    # Convert numeric columns
    numeric_cols = [
        'author_num_games_owned', 'author_num_reviews',
        'author_playtime_forever', 'author_playtime_last_two_weeks',
        'author_playtime_at_review', 'votes_up', 'votes_funny',
        'weighted_vote_score', 'comment_count'
    ]
    combined_df[numeric_cols] = combined_df[numeric_cols].apply(pd.to_numeric, errors='coerce')
    
    # Convert boolean columns
    bool_cols = [
        'voted_up', 'steam_purchase', 'received_for_free',
        'written_during_early_access', 'primarily_steam_deck'
    ]
    combined_df[bool_cols] = combined_df[bool_cols].astype(bool)
    
    # Convert timestamp columns
    time_cols = ['timestamp_created', 'timestamp_updated', 'author_last_played']
    for col in time_cols:
        combined_df[col] = pd.to_datetime(combined_df[col], unit='s', errors='coerce')
    
    # Save to CSV
    combined_df.to_csv(output_file, index=False)
    print(f"Saved {len(combined_df)} reviews to {output_file}")

if __name__ == "__main__":
    process_json_files()
# Out:
# Processing JSON files: 100%|██████████| 1005/1005 [00:19<00:00, 52.37it/s]
# Saved 674334 reviews to all_reviews.csv

# %%
import pandas as pd
import numpy as np
import contractions

# %%
df = pd.read_csv("all_reviews.csv")
df.head()
# Out:
# C:\Users\vnvtr\AppData\Local\Temp\ipykernel_57496\3053554390.py:1: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("all_reviews.csv")
#    recommendationid language  \
# 0         186822035  russian
# 1         186820701  english
# 2         186820524  english
# 3         186818112  russian
# 4         186818009  english
#
#                                               review    timestamp_created  \
# 0                                            WWW\r\n  2025-01-31 13:33:57
# 1                            ts crazy af so worth it  2025-01-31 13:12:02
# 2                                     best game ever  2025-01-31 13:09:11
# 3  хуйня для динозавров заходишь на сервер а там ...  2025-01-31 12:28:09
# 4  A Classic LAN-game. Childhood memories.\r\nNow...  2025-01-31 12:26:07
#
#      timestamp_updated  voted_up  votes_up  votes_funny  weighted_vote_score  \
# 0  2025-01-31 13:33:57      True         0            0                  0.0
# 1  2025-01-31 13:12:02      True         0            0                  0.0
# 2  2025-01-31 13:09:11      True         0            0                  0.0
# 3  2025-01-31 12:28:09     False         0            0                  0.0
# 4  2025-01-31 12:26:07      True         0            0                  0.0
#
#    comment_count  ...  author_num_games_owned  author_num_reviews  \
# 0              0  ...                       0                   3
# 1              0  ...                      47                  17
# 2              0  ...                       0                   1
# 3              0  ...                      28                   6
# 4              0  ...                       0                  16
#
#    author_playtime_forever  author_playtime_last_two_weeks  \
# 0                      550                             550
# 1                      112                             112
# 2                     2730                             985
# 3                       23                               0
# 4                     6683                               0
#
#    author_playtime_at_review   author_last_played  \
# 0                      550.0  2025-01-31 13:33:49
# 1                      112.0  2025-01-31 13:03:28
# 2                     2707.0  2025-01-31 14:09:25
# 3                       23.0  2023-04-21 12:16:58
# 4                     6683.0  2024-10-18 21:37:25
#
#    author_deck_playtime_at_review  game_id  timestamp_dev_responded  \
# 0                             NaN       10                      NaN
# 1                             NaN       10                      NaN
# 2                             NaN       10                      NaN
# 3                             NaN       10                      NaN
# 4                             NaN       10                      NaN
#
#    developer_response
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 25 columns]

# %%
df_en = df[df['language'] == 'english']
df_en.shape
# Out:
# (468002, 25)

# %%
df['timestamp_created'].astype('datetime64[ns]')
# Out:
# 0        2025-01-31 13:33:57
# 1        2025-01-31 13:12:02
# 2        2025-01-31 13:09:11
# 3        2025-01-31 12:28:09
# 4        2025-01-31 12:26:07
#                  ...
# 674329   2025-01-07 04:48:54
# 674330   2025-01-05 22:12:35
# 674331   2025-01-05 21:10:16
# 674332   2025-01-05 18:13:17
# 674333   2025-01-04 20:31:57
# Name: timestamp_created, Length: 674334, dtype: datetime64[ns]

# %%
df_en = df_en[df_en['timestamp_created'].astype('datetime64[ns]') > pd.to_datetime('2025-01-01')]
df_en.shape
# Out:
# (385423, 25)

# %%
df_en.rename(columns={'recommendationid': 'id',
                      'voted_up': 'score',
                      'review': 'content',
                      'author_steamid': 'author_id',
                      'game_id': 'app_id'}, inplace=True)
df_en['score'] = df_en['score'].astype(int)
df_en
# Out:
#                id language                                            content  \
# 1       186820701  english                            ts crazy af so worth it
# 2       186820524  english                                     best game ever
# 4       186818009  english  A Classic LAN-game. Childhood memories.\r\nNow...
# 5       186816922  english                                            Classic
# 11      186799829  english                                               goat
# ...           ...      ...                                                ...
# 674329  184991220  english                          Gone but not forgotten...
# 674330  184877197  english  pretty good game tbh, even tho i only played f...
# 674331  184872577  english  piece of shit game, can't even be bothered to ...
# 674332  184857864  english                                 controls are weird
# 674333  184772464  english                                 Yes. Play with me.
#
#           timestamp_created    timestamp_updated  score  votes_up  \
# 1       2025-01-31 13:12:02  2025-01-31 13:12:02      1         0
# 2       2025-01-31 13:09:11  2025-01-31 13:09:11      1         0
# 4       2025-01-31 12:26:07  2025-01-31 12:26:07      1         0
# 5       2025-01-31 12:06:19  2025-01-31 12:06:19      1         0
# 11      2025-01-31 05:52:42  2025-01-31 05:52:42      1         0
# ...                     ...                  ...    ...       ...
# 674329  2025-01-07 04:48:54  2025-01-07 04:48:54      1         0
# 674330  2025-01-05 22:12:35  2025-01-05 22:12:35      1         0
# 674331  2025-01-05 21:10:16  2025-01-05 21:10:16      0         4
# 674332  2025-01-05 18:13:17  2025-01-05 18:13:17      0         1
# 674333  2025-01-04 20:31:57  2025-01-04 20:31:57      1         0
#
#         votes_funny  weighted_vote_score  comment_count  ...  \
# 1                 0             0.000000              0  ...
# 2                 0             0.000000              0  ...
# 4                 0             0.000000              0  ...
# 5                 0             0.000000              0  ...
# 11                0             0.000000              0  ...
# ...             ...                  ...            ...  ...
# 674329            0             0.000000              0  ...
# 674330            0             0.000000              0  ...
# 674331            1             0.445714              0  ...
# 674332            0             0.000000              0  ...
# 674333            0             0.000000              0  ...
#
#         author_num_games_owned  author_num_reviews  author_playtime_forever  \
# 1                           47                  17                      112
# 2                            0                   1                     2730
# 4                            0                  16                     6683
# 5                            0                   4                     3206
# 11                           0                   4                     2999
# ...                        ...                 ...                      ...
# 674329                       0                  20                     1646
# 674330                       0                   2                       67
# 674331                     307                   6                       75
# 674332                       0                   1                        9
# 674333                       0                   7                    11107
#
#         author_playtime_last_two_weeks  author_playtime_at_review  \
# 1                                  112                      112.0
# 2                                  985                     2707.0
# 4                                    0                     6683.0
# 5                                   98                     3206.0
# 11                                  22                     2976.0
# ...                                ...                        ...
# 674329                               0                     1646.0
# 674330                               0                       67.0
# 674331                               0                       75.0
# 674332                               0                        9.0
# 674333                               0                    11079.0
#
#          author_last_played  author_deck_playtime_at_review  app_id  \
# 1       2025-01-31 13:03:28                             NaN      10
# 2       2025-01-31 14:09:25                             NaN      10
# 4       2024-10-18 21:37:25                             NaN      10
# 5       2025-01-31 12:06:06                             NaN      10
# 11      2025-01-31 06:18:01                             NaN      10
# ...                     ...                             ...     ...
# 674329  2025-01-07 04:48:13                             NaN   99900
# 674330  2025-01-05 22:09:57                             NaN   99900
# 674331  2025-01-05 21:09:34                             NaN   99900
# 674332  2025-01-05 18:12:41                             NaN   99900
# 674333  2025-01-13 19:35:49                             NaN   99900
#
#         timestamp_dev_responded  developer_response
# 1                           NaN                 NaN
# 2                           NaN                 NaN
# 4                           NaN                 NaN
# 5                           NaN                 NaN
# 11                          NaN                 NaN
# ...                         ...                 ...
# 674329                      NaN                 NaN
# 674330                      NaN                 NaN
# 674331                      NaN                 NaN
# 674332                      NaN                 NaN
# 674333                      NaN                 NaN
#
# [385423 rows x 25 columns]

# %%
validation_set = df_en[['id','app_id', 'author_id', 'content', 'score']]
validation_set['content'].astype(str)
validation_set['content'].dropna()
validation_set = validation_set[validation_set['content'].str.len() >= 10]
validation_set
# Out:
#                id  app_id          author_id  \
# 1       186820701      10  76561198861397461
# 2       186820524      10  76561197991630431
# 4       186818009      10  76561197993740346
# 13      186789771      10  76561199508598629
# 15      186782787      10  76561199675346350
# ...           ...     ...                ...
# 674329  184991220   99900  76561198355736866
# 674330  184877197   99900  76561199057223759
# 674331  184872577   99900  76561198122368726
# 674332  184857864   99900  76561199757360530
# 674333  184772464   99900  76561198035894500
#
#                                                   content  score
# 1                                 ts crazy af so worth it      1
# 2                                          best game ever      1
# 4       A Classic LAN-game. Childhood memories.\r\nNow...      1
# 13      The most friendly community i have ever seen. ...      1
# 15      The best version of cs to this day. Nothing wi...      1
# ...                                                   ...    ...
# 674329                          Gone but not forgotten...      1
# 674330  pretty good game tbh, even tho i only played f...      1
# 674331  piece of shit game, can't even be bothered to ...      0
# 674332                                 controls are weird      0
# 674333                                 Yes. Play with me.      1
#
# [308072 rows x 5 columns]

# %%
from langdetect import detect, DetectorFactory, LangDetectException

# Ensuring consistent results from langdetect
DetectorFactory.seed = 42

# Define a function to detect English comments
def is_english(text):
    try:
        return detect(text) == 'en'
    except LangDetectException:
        return False  # Handle empty or unreadable text

# Apply the language detection
validation_set['is_english'] = validation_set['content'].apply(is_english)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 14
#      11         return False  # Handle empty or unreadable text
#      13 # Apply the language detection
# ---> 14 validation_set['is_english'] = validation_set['content'].apply(is_english)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1209, in SeriesApply.apply(self)
#    1206     return self.apply_compat()
#    1208 # self.func is Callable
# -> 1209 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1289, in SeriesApply.apply_standard(self)
#    1283 # row-wise access
#    1284 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1285 # we need to give `na_action="ignore"` for categorical data.
#    1286 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1287 #  Categorical (GH51645).
#    1288 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1289 mapped = obj._map_values(
#    1290     mapper=curried, na_action=action, convert=self.convert_dtype
#    1291 )
#    1293 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1294     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1295     #  See also GH#25959 regarding EA support
#    1296     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2926, in pandas._libs.lib.map_infer()
#
# Cell In[8], line 9, in is_english(text)
#       7 def is_english(text):
#       8     try:
# ----> 9         return detect(text) == 'en'
#      10     except LangDetectException:
#      11         return False
#
# File ~\anaconda3\Lib\site-packages\langdetect\detector_factory.py:130, in detect(text)
#     128 detector = _factory.create()
#     129 detector.append(text)
# --> 130 return detector.detect()
#
# File ~\anaconda3\Lib\site-packages\langdetect\detector.py:136, in Detector.detect(self)
#     132 def detect(self):
#     133     '''Detect language of the target text and return the language name
#     134     which has the highest probability.
#     135     '''
# --> 136     probabilities = self.get_probabilities()
#     137     if probabilities:
#     138         return probabilities[0].lang
#
# File ~\anaconda3\Lib\site-packages\langdetect\detector.py:143, in Detector.get_probabilities(self)
#     141 def get_probabilities(self):
#     142     if self.langprob is None:
# --> 143         self._detect_block()
#     144     return self._sort_probability(self.langprob)
#
# File ~\anaconda3\Lib\site-packages\langdetect\detector.py:161, in Detector._detect_block(self)
#     159 i = 0
#     160 while True:
# --> 161     self._update_lang_prob(prob, self.random.choice(ngrams), alpha)
#     162     if i % 5 == 0:
#     163         if self._normalize_prob(prob) > self.CONV_THRESHOLD or i >= self.ITERATION_LIMIT:
#
# File ~\anaconda3\Lib\site-packages\langdetect\detector.py:212, in Detector._update_lang_prob(self, prob, word, alpha)
#     210 weight = alpha / self.BASE_FREQ
#     211 for i in xrange(len(prob)):
# --> 212     prob[i] *= weight + lang_prob_map[i]
#     213 return True
#
# KeyboardInterrupt:

# %%
validation_set
# Out:
#                id  app_id          author_id  \
# 1       186820701      10  76561198861397461
# 2       186820524      10  76561197991630431
# 4       186818009      10  76561197993740346
# 13      186789771      10  76561199508598629
# 15      186782787      10  76561199675346350
# ...           ...     ...                ...
# 674329  184991220   99900  76561198355736866
# 674330  184877197   99900  76561199057223759
# 674331  184872577   99900  76561198122368726
# 674332  184857864   99900  76561199757360530
# 674333  184772464   99900  76561198035894500
#
#                                                   content  score  is_english
# 1                                 ts crazy af so worth it      1        True
# 2                                          best game ever      1       False
# 4       A Classic LAN-game. Childhood memories.\r\nNow...      1        True
# 13      The most friendly community i have ever seen. ...      1        True
# 15      The best version of cs to this day. Nothing wi...      1        True
# ...                                                   ...    ...         ...
# 674329                          Gone but not forgotten...      1       False
# 674330  pretty good game tbh, even tho i only played f...      1        True
# 674331  piece of shit game, can't even be bothered to ...      0        True
# 674332                                 controls are weird      0        True
# 674333                                 Yes. Play with me.      1        True
#
# [308072 rows x 6 columns]

# %%
validation_set = validation_set[validation_set['is_english'] == True].drop(columns=['is_english'])
validation_set.shape

# %%
validation_set = pd.read_csv('preprocessed_validationset.csv')

# %%
# Text processing libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import re
from langdetect import detect, DetectorFactory, LangDetectException
nltk.download('wordnet')   #used in first run to download packages
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))


def PreProcessing_tokens(text):
    # Lowercasing text
    text = text.lower()
    # Removing numbers and symbols 
    text = re.sub(r'[^a-z\s]', '', text)
    # Using the contractions library to convert contracted text forms to their expanded version
    text = contractions.fix(text)
    # Tokenizing the text by words
    tokens = word_tokenize(text)
    # Applying lemmatization to the words not present in the stopwords set 
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    # Returning the joined preprocessed tokens
    return tokens

def PreProcessing_doc(text):
    tokens = PreProcessing_tokens(text)
    return ' '.join(tokens)

validation_set['cleaned_content'] = validation_set['content'].apply(PreProcessing_doc)
validation_set['tokens'] = validation_set['content'].apply(PreProcessing_tokens)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\vnvtr\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
validation_set = validation_set[validation_set['cleaned_content'] != '']
validation_set.to_csv('preprocessed_validationset.csv', index=False)

# %%
import kagglehub
import pandas as pd 
# Reading the dataset from the original source:
path = kagglehub.dataset_download("filipkin/steam-reviews")
# Printing dataset file path
print("Path to dataset files:", path)

games = pd.read_csv(f'{path}/output_steamspy.csv')
games
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.6), please consider upgrading to the latest version (0.3.8).
# Path to dataset files: C:\Users\vnvtr\.cache\kagglehub\datasets\filipkin\steam-reviews\versions\6
#        appid                       name                    owners
# 0         10             Counter-Strike  10,000,000 .. 20,000,000
# 1         20      Team Fortress Classic   5,000,000 .. 10,000,000
# 2         40         Deathmatch Classic   5,000,000 .. 10,000,000
# 3         50  Half-Life: Opposing Force    2,000,000 .. 5,000,000
# 4         60                   Ricochet   5,000,000 .. 10,000,000
# ..       ...                        ...                       ...
# 995  2835570          Buckshot Roulette    1,000,000 .. 2,000,000
# 996  2881650            Content Warning   5,000,000 .. 10,000,000
# 997  3070070    TCG Card Shop Simulator    1,000,000 .. 2,000,000
# 998  3097560                 Liar's Bar    2,000,000 .. 5,000,000
# 999  3146520                 WEBFISHING    1,000,000 .. 2,000,000
#
# [1000 rows x 3 columns]

# %%
# Calculating average game owners from the owners range column
def calculate_average_owners(range_str):
    try:
        # Split the range at ".." and strip commas while converting to int
        low, high = range_str.split('..')
        low = int(low.replace(',', '').strip())
        high = int(high.replace(',', '').strip())
        return (low + high) / 2  # Compute the average
    except Exception as e:
        print(f"Error processing range: {range_str} -> {e}")
        return None  # Return None for invalid entries


# Apply the function to the 'owners' column
games['average_owners'] = games['owners'].apply(calculate_average_owners)
# Check if any na arose
games.isnull().sum()
# Out:
# appid             0
# name              0
# owners            0
# average_owners    0
# dtype: int64

# %%
merge = pd.merge(validation_set,games, right_on='appid', left_on='app_id', how='inner')

# %%
merge = merge.drop(['appid', 'owners'], axis=1)
merge
# Out:
#                id  app_id          author_id  \
# 0       186820701      10  76561198861397461
# 1       186818009      10  76561197993740346
# 2       186789771      10  76561199508598629
# 3       186782787      10  76561199675346350
# 4       186781078      10  76561197960432447
# ...           ...     ...                ...
# 253808  185072995   99900  76561198954663339
# 253809  184877197   99900  76561199057223759
# 253810  184872577   99900  76561198122368726
# 253811  184857864   99900  76561199757360530
# 253812  184772464   99900  76561198035894500
#
#                                                   content  score  \
# 0                                 ts crazy af so worth it      1
# 1       A Classic LAN-game. Childhood memories.\r\nNow...      1
# 2       The most friendly community i have ever seen. ...      1
# 3       The best version of cs to this day. Nothing wi...      1
# 4       A legendary tactical shooter that shaped the g...      1
# ...                                                   ...    ...
# 253808  >downloads game\r\n>finishes tutorial\r\n>join...      1
# 253809  pretty good game tbh, even tho i only played f...      1
# 253810  piece of shit game, can't even be bothered to ...      0
# 253811                                 controls are weird      0
# 253812                                 Yes. Play with me.      1
#
#                                           cleaned_content  \
# 0                                        t crazy af worth
# 1       classic langame childhood memory infected peop...
# 2       friendly community ever seen playing group guy...
# 3                    best version c day nothing ever beat
# 4       legendary tactical shooter shaped genre simple...
# ...                                                   ...
# 253808  downloads game finish tutorial join friend cur...
# 253809  pretty good game tbh even tho played hat proba...
# 253810  piece shit game cant even bothered get hat fuc...
# 253811                                      control weird
# 253812                                           yes play
#
#                                                    tokens            name  \
# 0                           ['t', 'crazy', 'af', 'worth']  Counter-Strike
# 1       ['classic', 'langame', 'childhood', 'memory', ...  Counter-Strike
# 2       ['friendly', 'community', 'ever', 'seen', 'pla...  Counter-Strike
# 3       ['best', 'version', 'c', 'day', 'nothing', 'ev...  Counter-Strike
# 4       ['legendary', 'tactical', 'shooter', 'shaped',...  Counter-Strike
# ...                                                   ...             ...
# 253808  ['downloads', 'game', 'finish', 'tutorial', 'j...  Spiral Knights
# 253809  ['pretty', 'good', 'game', 'tbh', 'even', 'tho...  Spiral Knights
# 253810  ['piece', 'shit', 'game', 'cant', 'even', 'bot...  Spiral Knights
# 253811                               ['control', 'weird']  Spiral Knights
# 253812                                    ['yes', 'play']  Spiral Knights
#
#         average_owners
# 0           15000000.0
# 1           15000000.0
# 2           15000000.0
# 3           15000000.0
# 4           15000000.0
# ...                ...
# 253808       3500000.0
# 253809       3500000.0
# 253810       3500000.0
# 253811       3500000.0
# 253812       3500000.0
#
# [253813 rows x 9 columns]

# %%
merge.to_csv('preprocessed_validationset.csv', index=False)
